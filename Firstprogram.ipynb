# %% [markdown]
# <a href="https://colab.research.google.com/github/123456170/-Context-Driven-Agent/blob/main/Firstprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Yes i can learn physics")

# %%
print(123)
print(345)

# %%
5566

# %%
23+45

# %%
56-34

# %%
print(33)

# %%
"hello"

# %%
print("hello")
